# %%
from dma_mr import *
from opyrability import multimodel_rep, OI_eval
import numpy as np

# %%
# %matplotlib inline
# Defining AIS & DOS bounds.
DOS_bounds =  np.array([[70, 80],
                        [30, 45]])

AIS_bounds = np.array([[600, 1800],
                       [600, 1800]])
# Discretization Resolution.
AIS_resolution = [6, 6]

# Model assignment.
model = dma_mr_mv

# Obtain AOS.
AOS_region = multimodel_rep(model, 
                            AIS_bounds, 
                            AIS_resolution)

# Obtain Operability Index (OI).
OI = OI_eval(AOS_region, DOS_bounds)

# %%
import matplotlib.pyplot as plt
plt.xlabel("Modified X-Axis Label")
plt.draw()
