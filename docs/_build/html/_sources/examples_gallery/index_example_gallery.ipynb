# %% [markdown]
# # Examples Gallery
#
# The examples below use opyrability's functions/capabilities extensively for different
# tasks, such as:
#
# - Obtaining operability sets
# - Inverse mapping of operability sets
# - Evaluation of the Operability Index (OI)
# - Ranking of competing design/control structures using the OI as a metric
#
# All functions are used simultaneously to achieve design and control assessment
# tasks in representative case studies.
#
# Additionally, Opyrability enables users to integrate their own models from various commercial and open-source platforms, as well as machine learning surrogate models (ML surrogates). The following examples demonstrate operability studies conducted with external software and ML frameworks:

# %% [markdown]
# ### Case studies

# %% [markdown]
# |  |  |
# |--|--|
# | [Operability analysis of the Shower Problem](operability_index_shower.ipynb) | ![](../images/shower_oi.gif) |
# | [Operability analysis of a Direct Methane Aromatization Membrane Reactor (DMA-MR)](membrane_reactor.ipynb) | ![](../images/dma-mr.PNG) |
# | [Direct Air Capture example using AVEVA Process Simulation](aps_connection.ipynb) | ![](../images/m-DAC_ProcessPFD.png) |
# | [Sewage Sludge Gassification example using Aspen Plus](aspen_connection.ipynb) | ![](../images/aspen_flowsheet.png) |
# | [Air Separation Plant example using Unisim](unisim_connection.ipynb) | ![](../images/unisim_flowsheet.png) |
# | [Solid Oxide Electrolyzer Cell example using IDAES](idaes_connection.ipynb) | ![](../images/H_SOEC.png) |
# | [Operability Analysis of an Air Cooling System using DWSIM and Opyrability](dwsim_connection.ipynb) | ![](../images/air_cooling.png) |
# | [Operability analysis of the Shower Problem using Gaussian processes (GPs)](gp_surrogate_shower.ipynb) | ![](../images/shower_oi_gp.jpg) |
# | [Operability analysis of the DMA-MR process using Gaussian processes (GPs)](gp_surrogate_dma-mr.ipynb) | ![](../images/dma-schematic-ml.PNG) |
# | [Surrogate-Based Operability Analysis of a Heat Exchanger using the DWSIM process simulator and a Multi-Layer Perceptron (MLP)](mlp_DWSIM_heat_exchanger.ipynb) | ![](../images/heat_exchanger.png) |
# | [Dynamic operability analysis of a Direct Methane Aromatization Membrane Reactor (DMA-MR)](dynamic_dma_mr.ipynb) | ![](../images/dynamic-dma-mr-funnel.png) |
# | [Dynamic operability analysis of the HYPER cyber-physical fuel cell and gas turbine hybrid system](dynamic_hyper.ipynb) | ![](../images/hyper-funnel.png) |
# | [Comparing dynamic operability mapping methods (linear, nonlinear projection, n-step) on the DMA-MR](dynamic_methods_comparison.ipynb) | ![](../images/dynamic-methods-comparison.png) |
# | [Operability-based process intensification of the DMA-MR: P1, P2, P3 and the multilayer MILP](dma_mr_design_intensification.ipynb) | ![](../images/dma-mr-intensification.png) |
# | [Equation-oriented operability: Pyomo models in opyrability](pyomo_models_mapping.ipynb) | ![](../images/pyomo-mapping.png) |
# | [Inverse mapping with the Pounce solver](pounce_inverse_mapping.ipynb) | ![](../images/pounce-mapping.png) |
# | [Ranking process designs by the Operability Index](rank_designs.ipynb) | ![](../images/rank-designs.png) |
